# %%
import matplotlib.pyplot  as plt

# %%
import numpy as np

# %%
x = np.random.rand(50)
y = np.random.rand(50)

# %%
x
# Out:
# array([0.69443352, 0.90073998, 0.08528801, 0.60177998, 0.72799619,
#        0.67059566, 0.82806563, 0.03539394, 0.67691024, 0.18196388,
#        0.24972261, 0.91875242, 0.86832359, 0.6457817 , 0.821643  ,
#        0.62202895, 0.36295417, 0.52749291, 0.173068  , 0.03738224,
#        0.22690654, 0.68772055, 0.45912416, 0.13674172, 0.14500595,
#        0.31695892, 0.28130595, 0.41644168, 0.9378924 , 0.63530051,
#        0.77599542, 0.63471603, 0.55105685, 0.76532898, 0.70346264,
#        0.68583666, 0.96826261, 0.8473973 , 0.70138204, 0.55339527,
#        0.46269514, 0.85235132, 0.5917634 , 0.72973776, 0.09167959,
#        0.3909892 , 0.2424672 , 0.29088797, 0.64274297, 0.45944737])

# %%
y
# Out:
# array([0.66854077, 0.05833923, 0.85752369, 0.2977516 , 0.59344211,
#        0.70474358, 0.52801414, 0.29285245, 0.7058245 , 0.77071863,
#        0.55733468, 0.54024475, 0.86860896, 0.74811382, 0.41243627,
#        0.45313599, 0.82020831, 0.11179826, 0.74573271, 0.50880872,
#        0.63529121, 0.9743695 , 0.23926841, 0.67598997, 0.779197  ,
#        0.27435039, 0.63669097, 0.30707081, 0.38192804, 0.00846448,
#        0.19581285, 0.13111575, 0.82142058, 0.30336518, 0.12328118,
#        0.52984024, 0.81760066, 0.65167828, 0.77095982, 0.49011981,
#        0.19028545, 0.69289819, 0.11714393, 0.26812295, 0.85640102,
#        0.13412756, 0.95147999, 0.34744798, 0.91550508, 0.92525752])

# %%
plt.scatter(x,y)

# %%
plt.figure(figsize=(6,2))
plt.scatter(x,y,c='#FF0F25',alpha=1,marker='X')
plt.xlabel('This is my X-axis')
plt.ylabel('This is my Y-axis')
plt.title('This is my X vs Y Graph')
plt.grid()

# %%
x = np.linspace(1,10 ,100)
y = np.sin(x)

# %%
x
# Out:
# array([ 1.        ,  1.09090909,  1.18181818,  1.27272727,  1.36363636,
#         1.45454545,  1.54545455,  1.63636364,  1.72727273,  1.81818182,
#         1.90909091,  2.        ,  2.09090909,  2.18181818,  2.27272727,
#         2.36363636,  2.45454545,  2.54545455,  2.63636364,  2.72727273,
#         2.81818182,  2.90909091,  3.        ,  3.09090909,  3.18181818,
#         3.27272727,  3.36363636,  3.45454545,  3.54545455,  3.63636364,
#         3.72727273,  3.81818182,  3.90909091,  4.        ,  4.09090909,
#         4.18181818,  4.27272727,  4.36363636,  4.45454545,  4.54545455,
#         4.63636364,  4.72727273,  4.81818182,  4.90909091,  5.        ,
#         5.09090909,  5.18181818,  5.27272727,  5.36363636,  5.45454545,
#         5.54545455,  5.63636364,  5.72727273,  5.81818182,  5.90909091,
#         6.        ,  6.09090909,  6.18181818,  6.27272727,  6.36363636,
#         6.45454545,  6.54545455,  6.63636364,  6.72727273,  6.81818182,
# ...

# %%
y
# Out:
# array([ 0.84147098,  0.88704699,  0.92529707,  0.95590534,  0.978619  ,
#         0.99325047,  0.99967891,  0.99785123,  0.98778253,  0.96955595,
#         0.94332203,  0.90929743,  0.86776314,  0.8190622 ,  0.76359681,
#         0.70182505,  0.63425707,  0.56145091,  0.48400786,  0.40256749,
#         0.31780241,  0.23041267,  0.14112001,  0.05066187, -0.04021468,
#        -0.1307591 , -0.22022362, -0.30786935, -0.39297247, -0.47483011,
#        -0.55276624, -0.6261372 , -0.69433703, -0.7568025 , -0.8130177 ,
#        -0.86251837, -0.9048957 , -0.93979971, -0.96694212, -0.98609877,
#        -0.99711147, -0.99988924, -0.99440916, -0.98071647, -0.95892427,
#        -0.92921254, -0.89182665, -0.84707537, -0.79532828, -0.73701276,
#        -0.67261042, -0.60265314, -0.52771868, -0.44842592, -0.36542971,
#        -0.2794155 , -0.19109366, -0.10119362, -0.01045784,  0.0803643 ,
#         0.17052273,  0.25927286,  0.34588171,  0.429634  ,  0.50983804,
# ...

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
plt.plot(x,y,c='r')

# %%
plt.plot(x,y,'--r')

# %%
plt.figure(figsize=(8,2))
plt.plot(x,y,'--r')
plt.title('This is my sin wave graph')
plt.xlabel('This is my X-axis')
plt.ylabel('This is my Y-axis')
plt.grid()
plt.show()

# %%
x = ['a','b','c','d','e']
y = np.random.rand(5)

# %%
x
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
y
# Out:
# array([0.69173259, 0.81882498, 0.46115344, 0.29222881, 0.86284636])

# %%
plt.plot(x,y)

# %%
plt.figure(figsize=(5,3))
plt.bar(x,y,color='#710FFF')
plt.xlabel('Representing my cat data')
plt.ylabel('Representing my num data')
plt.title('This is my Bar Plot')
plt.grid()

# %%
plt.figure(figsize=(5,3))
plt.barh(x,y,color='#710FFF')
plt.xlabel('Representing my cat data')
plt.ylabel('Representing my num data')
plt.title('This is my Bar Plot')
plt.grid()

# %%
x = [1,2,3,4,5,6,7]
y = [2,3,4,5,6,7,8]

# %%
plt.figure(figsize=(6,2))
plt.plot(x,y)

# %%
plt.figure(figsize=(6,2))
plt.scatter(x,y)

# %%
data = [1,2,3,4,5,6,5,6,6,7,7,8,8,8,8,8]

# %%
plt.figure(figsize=(6,3))
plt.hist(data)
plt.grid()
plt.savefig('test.png')

# %%
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)
fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x,y,z,alpha=.9)
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [5, 4, 3, 2, 1]
plt.bar(x, y)
plt.show()

# %%
#SeaBorn

# %%
import seaborn as sns
import pandas as pd

# %%
iris = sns.load_dataset('iris')

# %%
#iris.set_index('sepal_length',inplace = True)
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(iris)
# Out:
# <AxesSubplot: >

# %%
sns.scatterplot(x = iris.sepal_length,y=iris.sepal_width)
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x = iris.sepal_length,y=iris.petal_length)
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.displot(iris.sepal_length)

# %%
import seaborn as sns
tips = sns.load_dataset('tips')
tips.head(4)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2

# %%
sns.scatterplot(x = tips.total_bill,y = tips.tip,data = tips,hue='smoker')
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.scatterplot(y = tips.total_bill,x = tips.smoker)
# Out:
# <AxesSubplot: xlabel='smoker', ylabel='total_bill'>

# %%
grouped = tips.groupby(['time','day'])

# %%
grouped['tip'].mean()
# Out:
# time    day
# Lunch   Thur    2.767705
#         Fri     2.382857
#         Sat          NaN
#         Sun          NaN
# Dinner  Thur    3.000000
#         Fri     2.940000
#         Sat     2.993103
#         Sun     3.255132
# Name: tip, dtype: float64

# %%
sns.scatterplot(y = tips.tip,x = tips.time)
# Out:
# <AxesSubplot: xlabel='time', ylabel='tip'>

# %%
tips['size'].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: size, dtype: int64

# %%
sns.scatterplot(x = tips.total_bill,y = tips.tip,data = tips,style='size')
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = tips.total_bill,y = tips.tip,data = tips,hue='time',style='size')
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(x = tips.total_bill,y = tips.tip,data = tips,hue='time',style='size')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x = tips.day,y=tips.total_bill)
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(x ='day',y='total_bill',data=tips)

# %%
sns.catplot(x ='smoker',y='tip',data=tips)

# %%
sns.jointplot(x =tips.total_bill,y=tips.tip,data=tips)

# %%
sns.pairplot(tips)#creates graphs for all the numerical columns.
